# %%
# if else

# %%
# height eligibility
print('Wellcome to the ride')
height  = int(input("enter the height in cm"))

if height>=120:
    print('u are good to ride')
else:
    print("u need to grow taller")
# Out:
# Wellcome to the ride
# enter the height in cm 121
# u are good to ride

# %%
# even or odd
print("welcome to even or odd identifier")
number = int(input("enter the number in int only"))

if number%2==0:
    print("the number is even")
else:
    print("number is odd")
# Out:
# welcome to even or odd identifier
# enter the number in int only 0
# the number is even

# %%
print('Wellcome to the ride')
height  = int(input("enter the height in cm"))

if height>=120:
    age = int(input("enter the "))
    if age <12:
        print('pay12')
    elif age<18:
        print("pay 14")
    else:
        age>18
        print("pay 20")
else:
    print("u need to grow taller")
# Out:
# Wellcome to the ride
# enter the height in cm 140
# enter the  34
# pay 20

# %% [markdown]
# ## BMI Calculator with interpretations

# %%
weight = 85
height = 1.85

bmi = weight / (height ** 2)

# 🚨 Do not modify the values above
# Write your code below 👇
if bmi < 18.5:
    print('underweight')
elif bmi<25:
    print('normal weight')
else:
    bmi>24
    print('overweight')
# Out:
# normal weight

# %% [markdown]
# ## ticket price detectorm

# %%
height = int(input("enter your height"))
age = int(input("enter the age"))
bill = []
if height>120:
    if age<12:
        bill = 2
        print("the child ticket is",bill)
    elif age<18:
        bill=3
        print("the teens ticket",bill)
    else :
        age>18
        bill = 4
        print("the adult ticket",bill)
    photo = input('do u want photos type y for yes and n for no')
    if photo=="y":
        bill+=3
    print('the total bill',bill)
else:
    print("get lost kid")
# Out:
# enter your height 140
# enter the age 15
# the teens ticket 3
# do u want photos type y for yes and n for no y
# the total bill 6

# %% [markdown]
# ## pythion pizza delivary

# %%
size = input('enter the size s,m or l')
peproni = input('do u want pp y or n ')
chees = input("do u want chees y or n")
bill = []
if size=='s':
    bill = 1
    if peproni=="y":
        bill+=1
    if chees=="y":
        bill+=1
    print("the bill",bill)
elif size == 'm':
    bill=2
    if peproni=="y":
        bill+=1
    if chees=="y":
        bill+=1
    print("the bill",bill)
else:
    size == 'l'
    bill=3
    if peproni=="y":
        bill+=1
    if chees=="y":
        bill+=1
    print("the bill",bill)
# Out:
# enter the size s,m or l s
# do u want pp y or n  y
# do u want chees y or n n
# the bill 2
