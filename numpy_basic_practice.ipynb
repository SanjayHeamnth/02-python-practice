# %% [markdown]
# # NUMPY
# NumPy (Numerical Python) is a powerful open-source Python library used for working with numerical data. It provides support for multi-dimensional arrays (like vectors, matrices, and tensors) and tools to perform mathematical operations on them efficiently

# %%
# importing  libraries
import numpy as np

# %% [markdown]
# # Numpyarrray
# A NumPy array (also called ndarray) is a grid of values (like numbers), all of the same type, and is indexed by a tuple of non-negative integers

# %%
# creating an empty list
narray = np.array([])
print(type(narray))
print(len(narray))
# Out:
# <class 'numpy.ndarray'>
# 0

# %%
narray
# Out:
# array([], dtype=float64)

# %%
# other way to crerat a empty ndarray
nan = np.array(object = None)# only exceptioon where  length is none
print(type(nan))
# Out:
# <class 'numpy.ndarray'>

# %%
nan
# Out:
# array(None, dtype=object)

# %%
# creating narray using list
some_list = [1,2,3,4]

# %%
n_list = np.array(object = some_list)

# %%
n_list.dtype
# Out:
# dtype('int32')

# %%
type(n_list)
# Out:
# numpy.ndarray

# %%
# can also store str in ndarray
n_arrr = np.array(["sanjay", "Abhi"])
type(n_arrr)
# Out:
# numpy.ndarray

# %%
n_type = np.array(object = [1,2,3,], dtype = int)

# %%
n_type1 = np.array(object = [1,2,3,], dtype = float)

# %%
n_same = nparray([1,2.2,3]) # all the element inside the array shoul be same dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 n_same = nparray([1,2.2,3])
#
# NameError: name 'nparray' is not defined

# %%
# interger will be converted to string
n_sd = np.array(["sanjay",3.4, "Abhi", '8\9'])
n_sd

# %%
# creating narray using tuple
n_t = (-1, 5,5,)
print(n_t, type(n_t))

# %%
n_t_a = np.array(n_t)
print(n_t_a, type(n_t_a))

# %% [markdown]
# ## creating a  ndarray using the set

# %%
seta = {'a',5.5,"sanjay"}
type(seta)

# %%
seta[0]

# %%
seta_na = np.array(seta)
print(seta_na, type(seta_na))

# %%
seta_na[1] # still not indexable

# %%
## from a misxtd list m

# %%
mixed_list = [['sanjay'], 1.2, 2, "abhi"]

# %%
type(mixed_list[2])

# %%
nda = np.array(mixed_list, )

# %%
nda = np.array(mixed_list, dtype = object )

# %%
# define a function to tt returns even number 
def even_numbers(n): return np.array([2*i for i in range(n)])

# %%
even_numbers(2222)

# %% [markdown]
# ## creating a 2d array

# %%
tow_d= np.array([[1,2,3], [4,5,6]])
print(tow_d)

# %%
import numpy as np

array_3d = np.array([[[ (i, j, k) for k in range(3)] for j in range(3)] for i in range(3)])
array_3d

# %% [markdown]
#  # Numpy array Attributes

# %%
n_arry =np.array([[1,-1],[0,1]])
n_arry

# %%
n_arry.ndim # give the dimension

# %%
n_arry.shape # shape give number of in=tems if u loook in a certain angle

# %%
len(n_arry.shape)

# %% [markdown]
# ## Acessing element in 1d array

# %%
np_arr = np.array([12,32,-43,22,78,-98])
np_arr
# Out:
# array([ 12,  32, -43,  22,  78, -98])

# %%
np_arr.ndim
# Out:
# 1

# %%
np_arr.shape
# Out:
# (6,)

# %%
len(np_arr)
# Out:
# 6

# %%
np_arr[2]
# Out:
# -43

# %%
np_arr[1:3]
# Out:
# array([ 32, -43])

# %%
np_arr[5:len(np_arr)]
# Out:
# array([-98])

# %%
np_arr[[0]]
# Out:
# array([12])

# %%
np_arr[:-1]
# Out:
# array([ 12,  32, -43,  22,  78])

# %%
np_arr[-1]
# Out:
# -98

# %%
# reversing  the np array
np_arr[::-1]
# Out:
# array([-98,  78,  22, -43,  32,  12])

# %% [markdown]
# ## accesing the elements in 2d array

# %%
npa = np.array([[1,2,3],[4,5,6]])
npa
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
